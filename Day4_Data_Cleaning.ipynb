# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Datasets/employee_data_messy (1).csv")

# %%
print("-----Data SUmmary -----")
df.info()
# Out:
# -----Data SUmmary -----
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   35 non-null     int64
#  1   Name         35 non-null     str
#  2   Age          33 non-null     str
#  3   Salary       34 non-null     str
#  4   Department   34 non-null     str
#  5   JoiningDate  34 non-null     str
#  6   Email        34 non-null     str
#  7   City         34 non-null     str
# dtypes: int64(1), str(7)
# memory usage: 4.5 KB

# %%
print("---- Missing Value Tally ----")
print(df.isnull().sum())
# Out:
# ---- Missing Value Tally ----
# EmployeeID     0
# Name           0
# Age            2
# Salary         1
# Department     1
# JoiningDate    1
# Email          1
# City           1
# dtype: int64

# %%
#Handling missing values
#Dropping: if one field is empty then the whole row is removed
#Imputation: Replacing missing cell with a valid statistical substistical substitute like mean, median, or other so calcuation is unbroken

#Drop rows where critical identifying criteria is missing (eg: Name)
df_clean=df.dropna(subset=["Name"])
print(df_clean)
# Out:
#     EmployeeID                Name           Age  Salary  Department  \
# 0          101           John Doe             25   50000          IT
# 1          102          Jane Smith            28   55000          HR
# 2          103        Mike Johnson           NaN   62000     Finance
# 3          104        Sarah Wilson        Thirty   58000          IT
# 4          105         David Brown            35     NaN   Marketing
# 5          106         Emily Davis            29   53000          HR
# 6          107        Chris Taylor            31   61000     Finance
# 7          108      Jessica Miller            27   49000          IT
# 8          109        Robert White            40   75000  Management
# 9          110          Lisa Green            26   51000          HR
# 10         111           John Doe             25   50000          IT
# 11         112         Alex Turner            22   45000          it
# 12         113         Maria Lopez                 56000     Finance
# 13         114          Kevin Hall            33   70000   MARKETING
# 14         115         Nancy Allen            29   52000          HR
# 15         116         Peter Young            41   82000  Management
# 16         117         Olivia King            24   48000          IT
# 17         118        Daniel Scott           NaN   57000     Finance
# 18         119         Emma Walker            30   61000          HR
# 19         120         James Adams            28   53000         NaN
# 20         121        Sophia Baker            27   50000          IT
# 21         122       Michael Clark            34   69000     Finance
# 22         123      Isabella Lewis            31   64000   Marketing
# 23         124         William Lee            45   90000  Management
# 24         125          Ava Harris            23   47000          IT
# 25         126        Ethan Martin            32   65000     Finance
# 26         127        Mia Thompson            29   54000          HR
# 27         128         Noah Garcia            27   51000          IT
# 28         129  Charlotte Martinez            36   72000   Marketing
# 29         130       Liam Robinson            38   78000  Management
# 30         131            john doe            25   50000          IT
# 31         132     Grace Rodriguez  twenty-eight   59000          HR
# 32         133      Benjamin Lewis            30  60,000     Finance
# 33         134       Amelia Walker            26   52000         IT
# 34         135          Lucas Hall            29   54000          hr
#
#    JoiningDate                         Email        City
# 0   2022-01-15            john.doe@gmail.com   Kathmandu
# 1   2021-11-10          jane.smith@gmail.com     Pokhara
# 2   2020-05-20        mike.johnson@gmail.com    Lalitpur
# 3   2022-03-12        sarah.wilson@gmail.com   Bhaktapur
# 4   2019-07-01         david.brown@gmail.com      Butwal
# 5   2021/08/15         emily.davis@gmail.com     Chitwan
# 6          NaN        chris.taylor@gmail.com      Dharan
# 7   2022-09-18                           NaN   Kathmandu
# 8   2018-12-05        robert.white@gmail.com     Pokhara
# 9   2023-02-10              lisa.green@gmail    Janakpur
# 10  2022-01-15            john.doe@gmail.com   Kathmandu
# 11  2023-06-20         alex.turner@gmail.com   Kathmandu
# 12  2021-04-25         maria.lopez@gmail.com    Lalitpur
# 13  2019-09-10          kevin.hall@gmail.com  Biratnagar
# 14  2022-07-11         nancy.allen@gmail.com     Pokhara
# 15  2017-03-14         peter.young@gmail.com      Dharan
# 16  2023-01-05         olivia.king@gmail.com   Bhaktapur
# 17  2020-08-19        daniel.scott@gmail.com    Lalitpur
# 18  2021-12-30         emma.walker@gmail.com   Kathmandu
# 19  2022-05-16         james.adams@gmail.com      Butwal
# 20  2023-03-11        sophia.baker@gmail.com     Pokhara
# 21  2019-11-22       michael.clark@gmail.com      Dharan
# 22  2020-07-18      isabella.lewis@gmail.com         NaN
# 23  2016-10-09         william.lee@gmail.com   Kathmandu
# 24  2023-04-14          ava.harris@gmail.com   Bhaktapur
# 25  2020-02-27        ethan.martin@gmail.com    Lalitpur
# 26  2021-06-06        mia.thompson@gmail.com     Pokhara
# 27  2022-08-30         noah.garcia@gmail.com      Dharan
# 28  2018-05-12  charlotte.martinez@gmail.com  Biratnagar
# 29  2017-09-21       liam.robinson@gmail.com   Kathmandu
# 30  2022-01-15            john.doe@gmail.com   Kathmandu
# 31  2021-10-10     grace.rodriguez@gmail.com     Pokhara
# 32  2020-03-15      benjamin.lewis@gmail.com    Lalitpur
# 33  2022-12-01       amelia.walker@gmail.com   Bhaktapur
# 34  2021-05-08          lucas.hall@gmail.com      Dharan

# %%
#Imputing and converting non numeric values
df_clean["Salary"]=df_clean["Salary"].astype(str).replace(',','',regex=True)
df_clean["Salary"]=pd.to_numeric(df_clean["Salary"], errors="coerce")
print(df_clean[["EmployeeID","Salary"]])
# Out:
#     EmployeeID   Salary
# 0          101  50000.0
# 1          102  55000.0
# 2          103  62000.0
# 3          104  58000.0
# 4          105      NaN
# 5          106  53000.0
# 6          107  61000.0
# 7          108  49000.0
# 8          109  75000.0
# 9          110  51000.0
# 10         111  50000.0
# 11         112  45000.0
# 12         113  56000.0
# 13         114  70000.0
# 14         115  52000.0
# 15         116  82000.0
# 16         117  48000.0
# 17         118  57000.0
# 18         119  61000.0
# 19         120  53000.0
# 20         121  50000.0
# 21         122  69000.0
# 22         123  64000.0
# 23         124  90000.0
# 24         125  47000.0
# 25         126  65000.0
# 26         127  54000.0
# 27         128  51000.0
# 28         129  72000.0
# 29         130  78000.0
# 30         131  50000.0
# 31         132  59000.0
# 32         133  60000.0
# 33         134  52000.0
# 34         135  54000.0

# %%
salary_median=df_clean["Salary"].median()
df_clean["Salary"]=df_clean["Salary"].fillna(salary_median)

# %%
#Replace missing Categorical fields (Departments) with label
df_clean["Department"]=df_clean["Department"].fillna("Unassigned")
print(df_clean["Department"])
# Out:
# 0             IT
# 1             HR
# 2        Finance
# 3             IT
# 4      Marketing
# 5             HR
# 6        Finance
# 7             IT
# 8     Management
# 9             HR
# 10            IT
# 11            it
# 12       Finance
# 13     MARKETING
# 14            HR
# 15    Management
# 16            IT
# 17       Finance
# 18            HR
# 19    Unassigned
# 20            IT
# 21       Finance
# 22     Marketing
# 23    Management
# 24            IT
# 25       Finance
# 26            HR
# 27            IT
# 28     Marketing
# 29    Management
# 30            IT
# 31            HR
# 32       Finance
# 33           IT
# 34            hr
# Name: Department, dtype: str

# %%
print("Missing Values after Initial Fixex")
print(df_clean.isnull().sum()[["Name","Salary","Department"]])
# Out:
# Missing Values after Initial Fixex
# Name          0
# Salary        0
# Department    0
# dtype: int64

# %%
duplicate_count=df_clean.duplicated().sum()
print(f"Total Perfect duplicate rows found: {duplicate_count}")
# Out:
# Total Perfect duplicate rows found: 0

# %%
#Dropping redundant rows
df_clean=df_clean.drop_duplicates()
print(f"Total Valid Unique Records  Remaining: {len(df_clean)}")
# Out:
# Total Valid Unique Records  Remaining: 35

# %%
df_clean["Age"]=df_clean["Age"].replace("Thirty",30)
df_clean["Age"]=df_clean["Age"].replace("twenty-eight",28)

# %%
df_clean["Age"]=pd.to_numeric(df_clean["Age"],errors='coerce')
age_median=df_clean["Age"].median()
df_clean["Age"]=df_clean["Age"].fillna(age_median).astype(int)

# %%
df_clean["JoiningDate"]= pd.to_datetime(df_clean["JoiningDate"], errors='coerce')

# %%
print("---- Structural Data Type Conversion Verified ----")
print(df_clean[["Age","JoiningDate"]].dtypes)
# Out:
# ---- Structural Data Type Conversion Verified ----
# Age                     int64
# JoiningDate    datetime64[us]
# dtype: object

# %%
df_clean["Name"]=df_clean["Name"].str.strip()
df_clean["City"]=df_clean["City"].str.strip()
df_clean["Name"]=df_clean["Name"].str.title()
df_clean["City"]=df_clean["City"].str.title()

# %%
df_clean["Department"]=df_clean["Department"].str.upper()

# %%
df_clean["City"]=df_clean["City"].fillna("Unknown")

# %%
print("----Cleaned Text Field----")
print(df_clean[["Name","Department","City"]].head(10))
# Out:
# ----Cleaned Text Field----
#              Name  Department       City
# 0        John Doe          IT  Kathmandu
# 1      Jane Smith          HR    Pokhara
# 2    Mike Johnson     FINANCE   Lalitpur
# 3    Sarah Wilson          IT  Bhaktapur
# 4     David Brown   MARKETING     Butwal
# 5     Emily Davis          HR    Chitwan
# 6    Chris Taylor     FINANCE     Dharan
# 7  Jessica Miller          IT  Kathmandu
# 8    Robert White  MANAGEMENT    Pokhara
# 9      Lisa Green          HR   Janakpur

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   35 non-null     int64
#  1   Name         35 non-null     str
#  2   Age          35 non-null     int64
#  3   Salary       35 non-null     float64
#  4   Department   35 non-null     str
#  5   JoiningDate  33 non-null     datetime64[us]
#  6   Email        34 non-null     str
#  7   City         35 non-null     str
# dtypes: datetime64[us](1), float64(1), int64(2), str(4)
# memory usage: 3.9 KB

# %%
df_clean["Email"]=df_clean["Email"].fillna("Unknown")

# %%
df_clean
# Out:
#     EmployeeID                Name  Age   Salary  Department JoiningDate  \
# 0          101            John Doe   25  50000.0          IT  2022-01-15
# 1          102          Jane Smith   28  55000.0          HR  2021-11-10
# 2          103        Mike Johnson   29  62000.0     FINANCE  2020-05-20
# 3          104        Sarah Wilson   30  58000.0          IT  2022-03-12
# 4          105         David Brown   35  55500.0   MARKETING  2019-07-01
# 5          106         Emily Davis   29  53000.0          HR         NaT
# 6          107        Chris Taylor   31  61000.0     FINANCE         NaT
# 7          108      Jessica Miller   27  49000.0          IT  2022-09-18
# 8          109        Robert White   40  75000.0  MANAGEMENT  2018-12-05
# 9          110          Lisa Green   26  51000.0          HR  2023-02-10
